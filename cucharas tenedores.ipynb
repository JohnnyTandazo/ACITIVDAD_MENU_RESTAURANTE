# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnnyTandazo/ACITIVDAD_MENU_RESTAURANTE/blob/main/cucharas%20tenedores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir tenedores2

# %%
#Entrar en cada carpeta y descomprimir el archivo zip
# %cd cuchillos
# !unzip cuchillos.zip
# %cd ..

# %cd tenedores2
# !unzip tenedores.zip
# %cd ..
# %cd cucharas
# !unzip cucharas.zip
# %cd ..
# Out:
# /content/cuchillos
# Archive:  cuchillos.zip
# replace image.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename: /content
# /content/tenedores2
# Archive:  tenedores.zip
#  extracting: image.jpeg
#  extracting: image.png
#  extracting: image (1).png
#  extracting: image (1).jpeg
#  extracting: AF2bZyjEaJublTOvFSQ9hW1ZbUIJCSYiSbu4vAI8FzSH4UToag-s32-c-mo.png
#  extracting: images.png
#  extracting: images.jpeg
#  extracting: images (1).jpeg
#  extracting: images (2).jpeg
#  extracting: images (3).jpeg
#  extracting: image (2).jpeg
#  extracting: images (4).jpeg
#  extracting: images (5).jpeg
#  extracting: image (2).png
#  extracting: image (3).jpeg
#  extracting: image (4).jpeg
#  extracting: image (5).jpeg
#  extracting: image (6).jpeg
#  extracting: image (3).png
#  extracting: image (7).jpeg
#  extracting: image (8).jpeg
#  extracting: image (9).jpeg
#  extracting: image (4).png
#  extracting: image (10).jpeg
#  extracting: image (11).jpeg
#  extracting: image (12).jpeg
# ...

# %%
#Borrar los archivo ZIP
# !rm -rf /content/cucharas/cucharas - Buscar con Google - 23_7_2025 11-09-41.zip
# !rm -rf /content/cuchillos/cuchillos - Buscar con Google - 23_7_2025 11-25-06.zip
# !rm -rf /content/tenedores2/tenedores.zip
# /content/cucharas/cucharas

# %%
#Mostrar cuantas imagenes tengo de cada categoria
# !ls /content/cucharas| wc -l #475
# !ls /content/cuchillos| wc -l #515
# !ls /content/tenedores2| wc -l #419
# Out:
# 129
# 224
# 193

# %%
#Mostrar algunas imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/tenedores2'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)
